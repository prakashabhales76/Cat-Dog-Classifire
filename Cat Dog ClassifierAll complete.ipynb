# %% [markdown]
# # Cat Dog Classifier

# %%
pip install tensorflow-gpu
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [39 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\moham\anaconda3\envs\tensor\lib\site-packages\setuptools\_vendor\packaging\requirements.py", line 35, in __init__
#       parsed = parse_requirement(requirement_string)
#     File "C:\Users\moham\anaconda3\envs\tensor\lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 64, in parse_requirement
#       return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#     File "C:\Users\moham\anaconda3\envs\tensor\lib\site-packages\setuptools\_vendor\packaging\_parser.py", line 82, in _parse_requirement
#       url, specifier, marker = _parse_requirement_details(tokenizer)
# ...

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
import os

# Set the CUDA_VISIBLE_DEVICES environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# Run your script
 'Cat Dog Classifier'.ipynb
# Out:
# python: can't open file "C:\\Users\\moham\\Great Learning DSE Program\\Demo - David Pradhap\\'Cat": [Errno 2] No such file or directory

# %%
import os,shutil
import tensorflow

# %%
import shutil

# Specify the directory path you want to remove
directory = original_dataset_dir

# Remove the directory
shutil.rmtree(directory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 7
#       4 directory = original_dataset_dir
#       6 # Remove the directory
# ----> 7 shutil.rmtree(directory)
#
# File ~\anaconda3\envs\tensor\lib\shutil.py:749, in rmtree(path, ignore_errors, onerror)
#     747     # can't continue even if onerror hook returns
#     748     return
# --> 749 return _rmtree_unsafe(path, onerror)
#
# File ~\anaconda3\envs\tensor\lib\shutil.py:600, in _rmtree_unsafe(path, onerror)
#     598         entries = list(scandir_it)
#     599 except OSError:
# --> 600     onerror(os.scandir, path, sys.exc_info())
#     601     entries = []
#     602 for entry in entries:
#
# File ~\anaconda3\envs\tensor\lib\shutil.py:597, in _rmtree_unsafe(path, onerror)
#     595 def _rmtree_unsafe(path, onerror):
#     596     try:
# --> 597         with os.scandir(path) as scandir_it:
# ...

# %% [markdown]
# # Step 1: Create Directories for training and validation for testing

# %%
original_dataset_dir="C:/Users/Class Room/Desktop/mlops_1,2/kaggle_original_data/train"

# %%
base_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small"
os.mkdir(base_dir)

# %%
train_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/train"
os.mkdir(train_dir)

# %%
test_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/test"
os.mkdir(test_dir)

# %%
validation_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/validation"
os.mkdir(validation_dir)

# %%
train_cats_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/train/cats"
os.mkdir(train_cats_dir)

# %%
train_dogs_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/train/dogs"
os.mkdir(train_dogs_dir)

# %%
test_cats_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/test/cats"
os.mkdir(test_cats_dir)
test_dogs_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/test/dogs"
os.mkdir(test_dogs_dir)

# %%
validation_cats_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/validation/cats"
os.mkdir(validation_cats_dir)
validation_dogs_dir="C:/Users/Class Room/Desktop/mlops_1,2/cats_dogs_small/validation/dogs"
os.mkdir(validation_dogs_dir)

# %%
fnames=['cat.{}.jpg'.format(i) for i in range(1000)]
for fname in fnames:
    src=os.path.join(original_dataset_dir,fname)
    dst=os.path.join(train_cats_dir,fname)
    shutil.copyfile(src,dst)

# %%
fnames=['dog.{}.jpg'.format(i) for i in range(1000)]
for fname in fnames:
    src=os.path.join(original_dataset_dir,fname)
    dst=os.path.join(train_dogs_dir,fname)
    shutil.copyfile(src,dst)

# %%
fnames=['cat.{}.jpg'.format(i) for i in range(1000,1500)]
for fname in fnames:
    src=os.path.join(original_dataset_dir,fname)
    dst=os.path.join(validation_cats_dir,fname)
    shutil.copyfile(src,dst)
    
fnames=['dog.{}.jpg'.format(i) for i in range(1000,1500)]
for fname in fnames:
    src=os.path.join(original_dataset_dir,fname)
    dst=os.path.join(validation_dogs_dir,fname)
    shutil.copyfile(src,dst)

# %%
fnames=['cat.{}.jpg'.format(i) for i in range(1500,2000)]
for fname in fnames:
    src=os.path.join(original_dataset_dir,fname)
    dst=os.path.join(test_cats_dir,fname)
    shutil.copyfile(src,dst)
    
fnames=['dog.{}.jpg'.format(i) for i in range(1500,2000)]
for fname in fnames:
    src=os.path.join(original_dataset_dir,fname)
    dst=os.path.join(test_dogs_dir,fname)
    shutil.copyfile(src,dst)

# %%
print('No. of training cat images =',len(os.listdir(train_cats_dir)))
print('No. of validation cat images =',len(os.listdir(validation_cats_dir)))
print('No. of test cat images =',len(os.listdir(test_cats_dir)))
print('No. of training dogs images =',len(os.listdir(train_dogs_dir)))
print('No. of validation dogs images =',len(os.listdir(validation_dogs_dir)))
print('No. of test dogs images =',len(os.listdir(test_dogs_dir)))
# Out:
# No. of training cat images = 1000
# No. of validation cat images = 500
# No. of test cat images = 500
# No. of training dogs images = 1000
# No. of validation dogs images = 500
# No. of test dogs images = 500

# %% [markdown]
# # Step 2: Instantiate a CNN Model

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Optimizer
from tensorflow.keras.optimizers import RMSprop

def create_model():
    model=Sequential()
    model.add(Conv2D(32,(3,3),input_shape=(150,150,3),activation='relu'))
    model.add(MaxPooling2D(2,2))

    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPooling2D(2,2))

    model.add(Conv2D(128,(3,3),activation='relu'))
    model.add(MaxPooling2D(2,2))

    model.add(Conv2D(128,(3,3),activation='relu'))
    model.add(MaxPooling2D(2,2))
    model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense(512,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))        
    model.compile(loss='binary_crossentropy',optimizer=RMSprop(learning_rate=0.0002),metrics=['acc'])
    return model

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_1 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 1)                 513
#
# ...
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# ...

# %%
from tensorflow.keras.optimizers import Optimizer
from tensorflow.keras.optimizers import RMSprop
model.compile(loss='binary_crossentropy',optimizer=RMSprop(learning_rate=0.0002),metrics=['acc'])

# %% [markdown]
# # Preprocess the training and validation images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(rescale=1./255)
test_datagen=ImageDataGenerator(rescale=1./255)

train_generator=train_datagen.flow_from_directory(
train_dir,
target_size=(150,150),
batch_size=20,
class_mode='binary')

validation_generator=test_datagen.flow_from_directory(
validation_dir,
target_size=(150,150),
batch_size=20,
class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
history=model.fit(
train_generator,
steps_per_epoch=100,
epochs=30,
validation_data=validation_generator,
validation_steps=50)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 38s 361ms/step - loss: 0.6931 - acc: 0.5400 - val_loss: 0.6835 - val_acc: 0.6160
# Epoch 2/30
# 100/100 [==============================] - 36s 355ms/step - loss: 0.6728 - acc: 0.6015 - val_loss: 0.6519 - val_acc: 0.6180
# Epoch 3/30
# 100/100 [==============================] - 32s 314ms/step - loss: 0.6321 - acc: 0.6510 - val_loss: 0.6145 - val_acc: 0.6630
# Epoch 4/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.5833 - acc: 0.6880 - val_loss: 0.6041 - val_acc: 0.6720
# Epoch 5/30
# 100/100 [==============================] - 27s 269ms/step - loss: 0.5490 - acc: 0.7250 - val_loss: 0.5814 - val_acc: 0.6950
# Epoch 6/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.5059 - acc: 0.7470 - val_loss: 0.6651 - val_acc: 0.6500
# Epoch 7/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.4790 - acc: 0.7600 - val_loss: 0.5613 - val_acc: 0.7090
# Epoch 8/30
# ...

# %%
#Evaluate the metrics
def plot_metrics(history, model):
    import matplotlib.pyplot as plt
    acc=model.history.history['acc']
    val_acc=model.history.history['val_acc']
    loss=model.history.history['loss']
    val_loss=model.history.history['val_loss']
    
    epochs=range(1,len(acc)+1)
    plt.plot(epochs,acc,'bo',label='Training Accuracy')
    plt.plot(epochs,val_acc,'b',label='Validation Accuracy')
    plt.title('Training Vs Validation Accuracy')
    plt.legend()
    plt.figure()
    plt.plot(epochs,loss,'bo',label='Training Loss')
    plt.plot(epochs,val_loss,'b',label='Validation Loss')
    plt.title('Training Vs Validation Loss')
    plt.legend()
    plt.show()

# %%
plt.style.use('ggplot')

# %%
plot_metrics(history)

# %%
model.save('cats_and_dogs_small.h5')

# %% [markdown]
#     The model is clearly overfitting and needs to be retrained with data augumentation

# %%
file='C:/Users/moham/Great Learning DSE Program/Demo - David Pradhap/cat.jpg'

# %%
import numpy as np

# %%
from PIL import Image

# Load the image
image = Image.open(file)

# Display the image
plt.imshow(image)
plt.show()

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
from PIL import Image
image=Image.open(file)
image=load_img(file, target_size=(150,150))
image=img_to_array(image)
image=np.expand_dims(image,axis=0)
model='cats_and_dogs_small.h5'
model=load_model(model)
pred=int(model.predict(image)[0][0])

if pred==1:
    print('DOG')
else:
    print('CAT')
# Out:
# 1/1 [==============================] - 0s 69ms/step
# CAT

# %% [markdown]
# # Modelling with Data Augumentation

# %% [markdown]
# Data Augmentation is a process to create more samples by performing transformation on images like vertical shift, shearing, rotation etc. It is used fo two purposes:
# 1. To increase the samppe size for smaller datsets
# 2. To regularize the model to prevent overfitting

# %% [markdown]
# ### Data Augmentation steps
# 1. rotation_range is a value in degrees (0-180), a range within which to randomly rotate pictures
# 2. width_shift and height_shift are ranges (as a fraction of total width or height) within which to randomly translate pictures vertically or horizontally
# 3. rescale is a value by which we will multiply the data before any other processing. Our original images consist in RGB coefficients in the 0-255, but such values would be too high for our models to process (given a typical learning rate), so we target values between 0 and 1 instead by scaling with a 1/255. factor.
# 4. shear_range is for randomly applying shearing transformations
# 5. zoom_range is for randomly zooming inside pictures
# 6. horizontal_flip is for randomly flipping half of the images horizontally --relevant when there are no assumptions of horizontal assymetry (e.g. real-world pictures).
# 7. fill_mode is the strategy used for filling in newly created pixels, which can appear after a rotation or a width/height shift.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rotation_range=50,
        width_shift_range=0.4,
        height_shift_range=0.4,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

test_datagen=ImageDataGenerator(rescale=1./255) # validation pictures are not to be augmented

train_generator=train_datagen.flow_from_directory(
train_dir,
batch_size=20,
target_size=(150, 150),
class_mode='binary')

validation_generator=test_datagen.flow_from_directory(
validation_dir,
batch_size=20,
target_size=(150, 150),
class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
model_with_aug=create_model()

# %%
model_with_aug.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 1)                 513
#
# ...
# Total params: 3,453,121
# Trainable params: 3,453,121
# ...

# %%
history=model_with_aug.fit(
train_generator,
steps_per_epoch=100,
epochs=10,
validation_data=validation_generator,
validation_steps=50)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 99s 967ms/step - loss: 0.6942 - acc: 0.4990 - val_loss: 0.6847 - val_acc: 0.5020
# Epoch 2/10
# 100/100 [==============================] - 72s 718ms/step - loss: 0.6831 - acc: 0.5395 - val_loss: 0.6636 - val_acc: 0.5790
# Epoch 3/10
# 100/100 [==============================] - 71s 711ms/step - loss: 0.6695 - acc: 0.5710 - val_loss: 0.6564 - val_acc: 0.6070
# Epoch 4/10
# 100/100 [==============================] - 70s 697ms/step - loss: 0.6635 - acc: 0.5805 - val_loss: 0.6530 - val_acc: 0.6110
# Epoch 5/10
# 100/100 [==============================] - 70s 703ms/step - loss: 0.6601 - acc: 0.5950 - val_loss: 0.6707 - val_acc: 0.5210
# Epoch 6/10
# 100/100 [==============================] - 70s 704ms/step - loss: 0.6523 - acc: 0.6050 - val_loss: 0.6471 - val_acc: 0.6080
# Epoch 7/10
# 100/100 [==============================] - 73s 728ms/step - loss: 0.6526 - acc: 0.6135 - val_loss: 0.6349 - val_acc: 0.6300
# Epoch 8/10
# ...

# %%
plot_metrics(history, model=model_with_aug)

# %%
model_with_aug.save('cats_dogs_small_2.h5')

# %% [markdown]
# ### with Transfer learning using pretrained Models

# %% [markdown]
# Transfer learninig is the art of using pretrained models for our computer visiosn tasks. These pretraiend models have trained with IMAGENET (14M images and 1000 classes) abd the weights are learned dn preseved for our use. These are avilable in Keras Applications . Some of the famous pretrained models are VGG16, ResNet50, Inception, MobileNet etc. In most cases we will retrain the pretrained model by freezing the conculution base and only trainijg a fully connected classifier on the top.

# %%
from tensorflow.keras.applications import VGG16

# %%
con_base=VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
# Out:
# ...
# 58889256/58889256 [==============================] - 7s 0us/step

# %%
con_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
# ...

# %%
# instantiate a model for training
transfer_model=Sequential()
transfer_model.add(con_base)
transfer_model.add(Flatten())
transfer_model.add(Dense(258, activation='relu'))
transfer_model.add(Dense(1, activation='sigmoid'))

# %%
transfer_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 258)               2113794
#
#  dense_3 (Dense)             (None, 1)                 259
#
# ...
# Total params: 16,828,741
# Trainable params: 16,828,741
# Non-trainable params: 0
# _________________________________________________________________

# %%
# freezing the convolution base
con_base.trainable=False

# %%
# train the VGG16 model with data augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rotation_range=50,
        width_shift_range=0.4,
        height_shift_range=0.4,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

test_datagen=ImageDataGenerator(rescale=1./255) # validation pictures are not to be augmented

train_generator=train_datagen.flow_from_directory(
train_dir,
batch_size=20,
target_size=(150, 150),
class_mode='binary')

validation_generator=test_datagen.flow_from_directory(
validation_dir,
batch_size=20,
target_size=(150, 150),
class_mode='binary')


transfer_model.compile(loss='binary_crossentropy', optimizer=RMSprop(learning_rate=0.00002),
                       metrics=['acc'])

history=transfer_model.fit(
train_generator, 
steps_per_epoch=100,
epochs=5,
validation_data=validation_generator,
validation_steps=50)
    
# this kind of training is very costly and would ideally require a GPU
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Epoch 1/5
# 100/100 [==============================] - 250s 2s/step - loss: 0.6501 - acc: 0.6095 - val_loss: 0.5312 - val_acc: 0.7430
# Epoch 2/5
# 100/100 [==============================] - 255s 3s/step - loss: 0.5757 - acc: 0.7090 - val_loss: 0.4552 - val_acc: 0.7990
# Epoch 3/5
# 100/100 [==============================] - 264s 3s/step - loss: 0.5356 - acc: 0.7340 - val_loss: 0.3972 - val_acc: 0.8530
# Epoch 4/5
# 100/100 [==============================] - 262s 3s/step - loss: 0.5007 - acc: 0.7645 - val_loss: 0.3573 - val_acc: 0.8710
# Epoch 5/5
# 100/100 [==============================] - 257s 3s/step - loss: 0.4727 - acc: 0.7815 - val_loss: 0.3385 - val_acc: 0.8680

# %% [markdown]
# Recommended Book:https://www.statlearning.com/

# %%
plot_metrics(history=history,model=transfer_model)

# %%
transfer_model.save('cats_dogs_small_3.h5')

# %% [markdown]
# ### Deploy the chosen model in streamlit

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from PIL import  Image

st.title('Cat Dog Classifier')

#Step 1 : Load the model
model=load_model('cats_dogs_small_3.h5')


# Step2: Load the image to predict
file_uploaded=st.file_uploader('Choose the database', accept_multiple_files=False)
if file_uploaded is not None:
    file_name=file_uploaded
else:
    file_name='image.jpg'
    
if st.checkbox('View Image', False):
    image=Image.open(file_name)
    st.image(image)
    
#Step3: Preprocess the image
img=load_img(file_name, target_size=(150, 150))
img_array=img_to_array(img)
img_array_final=np.expand_dims(img_array, axis=0)

# Step4: Predict the image and print the result
prediction=int(model.predict(img_array_final)[0][0])
if st.button("PREDICT"):
    if prediction==1:
        st.subheader("The image is a Dog")
    else:
        st.subheader("The image is a Cat")
# Out:
# Overwriting app.py

# %%
# %%writefile app1.py
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import streamlit as st
#step1 :load the model
model = ResNet50(weights='imagenet')

#step2: load the image
file_uploaded=st.file_uploader('Choose the database', accept_multiple_files=False)
if file_uploaded is not None:
    file_name=file_uploaded
else:
    file_name='image.jpg'
    
#step2: preprocess the image
img = image.load_img(file_name, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

#step4: get the result
preds = model.predict(x)
prediction=decode_predictions(preds, top=3)[0][0]
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
if st.button('Predict'):
    st.subheader(prediction )
# Out:
# Overwriting app1.py
